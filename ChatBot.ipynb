# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

import json
import pickle
import random
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
# Out:
# [nltk_data] Downloading package punkt to C:\Users\rahul/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\rahul/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!', ',']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatized words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
# initializing training data
training = []
output_empty = [0] * len(classes)

for doc in documents:
    # initializing bag of words
    bag = []
    
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)

# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data created")
# Out:
# Training data created

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 12ms/step - loss: 2.2746 - accuracy: 0.0426
# Epoch 2/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1297 - accuracy: 0.2766
# Epoch 3/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0989 - accuracy: 0.1702
# Epoch 4/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.9888 - accuracy: 0.3404
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.9937 - accuracy: 0.3191
# Epoch 6/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.8766 - accuracy: 0.4681
# Epoch 7/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.7109 - accuracy: 0.5106
# Epoch 8/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.5846 - accuracy: 0.5745
# Epoch 9/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.5817 - accuracy: 0.5745
# Epoch 10/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.4377 - accuracy: 0.4468
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1596 - accuracy: 0.7021
# Epoch 12/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1715 - accuracy: 0.6170
# Epoch 13/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0787 - accuracy: 0.7447
# Epoch 14/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8817 - accuracy: 0.7447
# Epoch 15/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8807 - accuracy: 0.7447
# Epoch 16/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8036 - accuracy: 0.7234
# Epoch 17/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6444 - accuracy: 0.8298
# Epoch 18/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4943 - accuracy: 0.9574
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6235 - accuracy: 0.8723
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7091 - accuracy: 0.8085
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4837 - accuracy: 0.8936
# Epoch 22/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7134 - accuracy: 0.7872
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4718 - accuracy: 0.8298
# Epoch 24/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4501 - accuracy: 0.8723
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.8723
# Epoch 26/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3406 - accuracy: 0.8936
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2975 - accuracy: 0.9149
# Epoch 28/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3399 - accuracy: 0.8936
# Epoch 29/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3083 - accuracy: 0.8511
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3010 - accuracy: 0.9362
# Epoch 31/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4109 - accuracy: 0.8723
# Epoch 32/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3094 - accuracy: 0.9574
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4134 - accuracy: 0.8511
# Epoch 34/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2862 - accuracy: 0.9149
# Epoch 35/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2030 - accuracy: 0.9574
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2115 - accuracy: 0.9787
# Epoch 37/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1567 - accuracy: 0.9787
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2503 - accuracy: 0.9362
# Epoch 39/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2112 - accuracy: 0.9362
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3831 - accuracy: 0.8723
# Epoch 41/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2389 - accuracy: 0.8936
# Epoch 42/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2779 - accuracy: 0.9149
# Epoch 43/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1186 - accuracy: 1.0000
# Epoch 44/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1147 - accuracy: 0.9787
# Epoch 45/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2659 - accuracy: 0.9149
# Epoch 46/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0681 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1446 - accuracy: 0.9362
# Epoch 48/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1261 - accuracy: 0.9787
# Epoch 49/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2064 - accuracy: 0.9149
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0918 - accuracy: 1.0000
# Epoch 51/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0926 - accuracy: 0.9787
# Epoch 52/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1828 - accuracy: 0.9149
# Epoch 53/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1444 - accuracy: 0.9574
# Epoch 54/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 55/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.9787
# Epoch 56/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0607 - accuracy: 1.0000
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0876 - accuracy: 1.0000
# Epoch 58/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0688 - accuracy: 0.9787
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1415 - accuracy: 0.9787
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0786 - accuracy: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9787
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0656 - accuracy: 0.9787
# Epoch 63/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0665 - accuracy: 0.9787
# Epoch 64/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0628 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0855 - accuracy: 0.9787
# Epoch 66/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1008 - accuracy: 0.9574
# Epoch 68/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1637 - accuracy: 0.9362
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0994 - accuracy: 1.0000
# Epoch 70/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0917 - accuracy: 0.9787
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0593 - accuracy: 0.9787
# Epoch 73/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1426 - accuracy: 0.9787
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0496 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0788 - accuracy: 0.9574
# Epoch 77/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0605 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 813us/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0500 - accuracy: 0.9787
# Epoch 81/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0407 - accuracy: 0.9787
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0544 - accuracy: 0.9787
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1146 - accuracy: 0.9574
# Epoch 87/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0944 - accuracy: 0.9787
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0569 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0672 - accuracy: 0.9787
# Epoch 92/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0535 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0415 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0488 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0506 - accuracy: 0.9787
# Epoch 100/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1141 - accuracy: 0.9574
# Epoch 101/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0385 - accuracy: 0.9787
# Epoch 104/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0825 - accuracy: 0.9787
# Epoch 105/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0475 - accuracy: 0.9787
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0511 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.9574
# Epoch 108/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0461 - accuracy: 0.9787
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0481 - accuracy: 0.9787
# Epoch 117/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0467 - accuracy: 0.9787
# Epoch 119/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.9787
# Epoch 121/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0916 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0360 - accuracy: 0.9787
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0412 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.9787
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0286 - accuracy: 0.9787
# Epoch 133/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1124 - accuracy: 0.9574
# Epoch 134/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0785 - accuracy: 0.9787
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0733 - accuracy: 0.9574
# Epoch 142/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 994us/step - loss: 0.0411 - accuracy: 0.9787
# Epoch 145/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0426 - accuracy: 0.9787
# Epoch 153/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0427 - accuracy: 0.9787
# Epoch 154/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0542 - accuracy: 0.9787
# Epoch 155/200
# 10/10 [==============================] - 0s 956us/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9787
# Epoch 158/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 866us/step - loss: 0.0392 - accuracy: 0.9787
# Epoch 163/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0270 - accuracy: 0.9787
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0461 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0374 - accuracy: 0.9787
# Epoch 170/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0278 - accuracy: 0.9787
# Epoch 172/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0641 - accuracy: 0.9787
# Epoch 174/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 0.9787
# Epoch 178/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0306 - accuracy: 0.9787
# Epoch 179/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9787
# Epoch 180/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - ETA: 0s - loss: 2.8761e-04 - accuracy: 1.00 - 0s 1ms/step - loss: 0.0504 - accuracy: 0.9787
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9787
# Epoch 188/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0389 - accuracy: 0.9787
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 0.9787
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0889 - accuracy: 0.9787
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# model created

# %%
from tensorflow.keras.models import load_model
model = load_model('chatbot_model.h5')

intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *

def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

base = Tk()
base.title("Hello")
base.geometry("400x460")
base.iconbitmap(r'icon.ico')
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="10", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command = send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")

#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=50, width=265)
SendButton.place(x=6, y=401, height=50)

base.mainloop()

# %%
Button?
